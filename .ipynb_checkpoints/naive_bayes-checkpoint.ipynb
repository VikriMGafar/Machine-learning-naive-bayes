# %%
from scipy.io import arff
import pandas as pd

data = arff.loadarff('./caesarian.csv.arff')
# print(data)
df = pd.DataFrame(data[0])

df.head()
# Out:
#      Age Delivery number Delivery time Blood of Pressure Heart Problem  \
# 0  b'22'            b'1'          b'0'              b'2'          b'0'
# 1  b'26'            b'2'          b'0'              b'1'          b'0'
# 2  b'26'            b'2'          b'1'              b'1'          b'0'
# 3  b'28'            b'1'          b'0'              b'2'          b'0'
# 4  b'22'            b'2'          b'0'              b'1'          b'0'
#
#   Caesarian
# 0      b'0'
# 1      b'1'
# 2      b'0'
# 3      b'0'
# 4      b'1'

# %%
import pandas as pd
dataset = pd.read_csv("./caesarian.csv")
df = pd.DataFrame(dataset)
df.head()
# Out:
#                                                                                                                                    @relation caesarian
# @attribute 'Age' { 22              26   28  27  32  36  33.0 23.0 20.0 29.0 25.0 37.0 24.0 18.0 30.0 40.0 31.0 19.0 21.0 35.0 17.0               38 }
# @attribute 'Delivery number' { 1   2    3   4 } NaN NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN                  NaN
# @attribute 'Delivery time' { 0     1    2 } NaN NaN NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN                  NaN
# @attribute 'Blood of Pressure' { 2 1    0 } NaN NaN NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN                  NaN
# @attribute 'Heart Problem' { 1     0 }  NaN NaN NaN NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN                  NaN
